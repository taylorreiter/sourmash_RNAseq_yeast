# %%
sourmash compute ./*fa.gz

# %% [markdown]
# I ran the below code in terminal because I couldn't figure out how to run it in python.

# %%
sourmash compare -o yeast_syrah_WT ./*sig
# Out:
#   File "<ipython-input-1-84bc26541724>", line 1
#     sourmash compare ./*sig
#                    ^
# SyntaxError: invalid syntax

# %%
# %matplotlib inline
import numpy
from sourmash_lib import fig
import pylab

# %%
D, labels = fig.load_matrix_and_labels('yeast_syrah_WT')
D = (D + D.T) / 2.0
_ = fig.plot_composite_matrix(D, labels, vmin=0.48)
numpy.min(D), numpy.max(D)
pylab.savefig('WT_syrah_sourmash_heatmap.pdf')
