# %%
sourmash compare -o yeast_syrah_L3 ./*sig

# %%
# %matplotlib inline
import numpy
from sourmash_lib import fig
import pylab

# %%
D, labels = fig.load_matrix_and_labels('yeast_syrah_L3')
D = (D + D.T) / 2.0
_ = fig.plot_composite_matrix(D, labels, vmin=0.48)
numpy.min(D), numpy.max(D)
pylab.savefig('L3_syrah_sourmash_heatmap.pdf')
