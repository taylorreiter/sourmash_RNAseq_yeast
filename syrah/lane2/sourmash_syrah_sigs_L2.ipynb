# %%
sourmash compare -o yeast_syrah_L2 ./*sig #completed in terminal

# %%
# %matplotlib inline
import numpy
from sourmash_lib import fig
import pylab

# %%
D, labels = fig.load_matrix_and_labels('yeast_syrah_L2')
D = (D + D.T) / 2.0
_ = fig.plot_composite_matrix(D, labels, vmin=0.48)
numpy.min(D), numpy.max(D)
pylab.savefig('L2_syrah_sourmash_heatmap.pdf')

# %%
numpy.savetxt("L2_numpy.csv", D, delimiter=",")

# %%
D.shape
# Out:
# (96, 96)
