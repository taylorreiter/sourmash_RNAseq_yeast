# %%
sourmash compute ./*fa.gz

# %%
sourmash compare ./*sig

# %%
# %matplotlib inline
import numpy
from sourmash_lib import fig
import pylab

# %%
D, labels = fig.load_matrix_and_labels('yeast_syrah')
D = (D + D.T) / 2.0
_ = fig.plot_composite_matrix(D, labels, vmin=0.48)
numpy.min(D), numpy.max(D)
plt.figure(figsize=(20,10))
pylab.savefig('foo.pdf')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-5db290ea11d7> in <module>()
#       3 _ = fig.plot_composite_matrix(D, labels, vmin=0.48)
#       4 numpy.min(D), numpy.max(D)
# ----> 5 plt.figure(figsize=(20,10))
#       6 pylab.savefig('foo.pdf')
#
# NameError: name 'plt' is not defined
